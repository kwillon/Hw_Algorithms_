# %% [markdown]
# # **Hometask 1**
# 1. Upload qm9.csv dataset on your server
# 2. Find your personal random state in the “students list” table
# 3. Sample 20k rows from qm9 dataset using your personal random state

# %%
import pandas as pd

# %% [markdown]
# ##все о наши данных https://docs.google.com/document/d/17ldxvSUvejjlFffEHXYY7y9zfzEJ4LeQ/edit?usp=sharing&ouid=103434033417021616700&rtpof=true&sd=true
# Все наши свойства:
#
# **Smiles**: формула молекулы
# **A, B, C**: константы
# **mu**: дипольный момент [D]
# **alpha**: изотропная поляризуемость [a0^3]
# **homo, lumo**: энергия HOMO, LUMO [Ha]
# **gap**: разрыв (LUMO - HOMO) [Ha]
# **r2**: электронное пространственное распространение [a0^2]
# **zpve**: нулевая точка [Ha]
# **u0**: внутренняя энергия при 0 [Ha]

# %%
df = pd.read_csv('/content/qm9.csv')

# %%
df = df.sample(n=20000, random_state=6)
df
# Out:
#             mol_id             smiles        A        B        C      mu  \
# 50578    gdb_50579     O=CC1CCC2OC2C1  3.61423  1.09149  0.93260  2.0905
# 108156  gdb_108157   COC12CC=C3CC1C23  3.33497  1.50547  1.26311  1.5224
# 1879      gdb_1880       OC1CCC(=O)C1  5.59112  1.96604  1.53851  2.2377
# 34263    gdb_34264   N#CC12NC3CNC1C23  4.19762  1.34307  1.21397  5.2940
# 22037    gdb_22038   CC(=NO)CC(C)(C)C  2.79330  0.93080  0.84919  0.5406
# ...            ...                ...      ...      ...      ...     ...
# 41463    gdb_41464   C1OC23CCN=C2NC13  3.34284  1.73396  1.32936  3.1256
# 124393  gdb_124394   CC(C#C)C1=CON=C1  3.29901  1.16566  0.91521  2.9980
# 57323    gdb_57324  CC(C)(C)C(C#N)C#N  1.79871  1.63214  1.07089  4.5091
# 98645    gdb_98646  COC(=O)C1CC(=O)N1  4.65384  0.89755  0.83874  4.4515
# 114571  gdb_114572     CCC1OC2CC12C#N  2.81698  1.18586  0.96968  3.1090
#
#         alpha    homo    lumo     gap         r2      zpve          u0  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 50578 to 114571
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mol_id  20000 non-null  object
#  1   smiles  20000 non-null  object
#  2   A       20000 non-null  float64
#  3   B       20000 non-null  float64
#  4   C       20000 non-null  float64
#  5   mu      20000 non-null  float64
#  6   alpha   20000 non-null  float64
#  7   homo    20000 non-null  float64
#  8   lumo    20000 non-null  float64
#  9   gap     20000 non-null  float64
#  10  r2      20000 non-null  float64
#  11  zpve    20000 non-null  float64
#  12  u0      20000 non-null  float64
#  13  u298    20000 non-null  float64
#  14  h298    20000 non-null  float64
#  15  g298    20000 non-null  float64
#  16  cv      20000 non-null  float64
# dtypes: float64(15), object(2)
# memory usage: 2.7+ MB

# %% [markdown]
# Код для того, чтобы выгрузить из Colab большие файлы, так как есть ограничения на объем загрузки одного файла

# %%
# количество частей, на которые вы хотите разбить файл
num_parts = 5

# Определите размер каждой части
total_rows = len(df)
chunk_size = total_rows // num_parts

# Разделите DataFrame на части и сохраните каждую часть в отдельный файл
for i in range(num_parts):
    start_idx = i * chunk_size
    end_idx = start_idx + chunk_size
    if i == num_parts - 1:  # для последней части включите оставшиеся строки
        end_idx = total_rows
    df_chunk = df.iloc[start_idx:end_idx]
    df_chunk.to_csv(f'my_data_part_{i+1}.csv', encoding='utf-8', index=False)
